# %% [markdown]
# Data types in python

# %% [markdown]
# For storing number python has three main data types
# 1. integer - int (for storing real whole numbers, eg= 10, 11, -12)
# 2. floating point - (for strong real floating point numbers eg 10.1, -11.2 )
# 3. complex - (for storing complex number eg= 3 + 3j )

# %%
number= 1
print(type(number))
number= 1.1
print(type(number))
number= 2 + 2j
print(type(number))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
number= int(input("\n enter a number: "))
print(type(number))
# Out:
# <class 'int'>

# %%
name= "my name"
print(type(name))
selection= "A"
print(type(selection))

for letter in name:
    print(letter)
# Out:
# <class 'str'>
# <class 'str'>
# m
# y
#
# n
# a
# m
# e
